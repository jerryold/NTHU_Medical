# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, precision_score, recall_score, f1_score, accuracy_score, confusion_matrix

import glob
import cv2
import random

import tensorflow as tf

#print versions
print('tensorflow version',tf.__version__)

path=os.getcwd()
print(path)
# Out:
# tensorflow version 2.3.1
# /home/wcislab/NTHU_Medical

# %%
#Load Data
train_path = path+'/chest_xray/train'
val_path = path+'/chest_xray/val'
test_path = path+'/chest_xray/test2'
test_path2 = path+'/chest_xray/test'

# %%
train_files_original = glob.glob(train_path+'/*/*')
val_files_original = glob.glob(val_path+'/*/*')
test_files = glob.glob(test_path+'/*')




print('number of train samples across classes:', len(train_files_original))
print('number of val samples across classes:', len(val_files_original))
print('number of test samples across classes:', len(test_files))
# Out:
# number of train samples across classes: 5216
# number of val samples across classes: 16
# number of test samples across classes: 624

# %%
files = np.unique(train_files_original + val_files_original)
train_files, val_files = train_test_split(files, test_size=0.3, shuffle=True)

print('number of train samples:', len(train_files))
print('number of val samples:', len(val_files))
# Out:
# number of train samples: 3662
# number of val samples: 1570

# %%
count_normal = len([x for x in train_files if 'NORMAL' in x])
count_pneumonia = len([x for x in train_files if 'PNEUMONIA' in x])

print('Count of NORMAL images in train:', count_normal)
print('Count of PNEUMONIA images in train:', count_pneumonia)
# Out:
# Count of NORMAL images in train: 951
# Count of PNEUMONIA images in train: 2711

# %%
IMG_SIZE = 180
def process_inputs(files_list):
    data = []
    for file in files_list:
        try:
      # figure out label
          parts = file.split('/')
          assert parts[-2] in ['NORMAL', 'PNEUMONIA']
          label = 1 if parts[-2] == "PNEUMONIA" else 0

      # figure out image pixel array
          img_arr = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
          resized_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
        except Exception as e:
            raise Exception(e)
        data.append([resized_arr, label])
    return np.array(data)

# %%
train = process_inputs(train_files)
val = process_inputs(val_files)
# test2 = process_inputs(test_files)

# %%
test_data = []
img_handle=[]
IMG_SIZE = 180



for line in test_files:
    Type=line.split("/")[-1]
    img_handle.append(Type)
print(img_handle)


for img in test_files:
    img_arr = cv2.imread(img,cv2.IMREAD_GRAYSCALE)
    resized_arr = cv2.resize(img_arr, (IMG_SIZE ,IMG_SIZE))
    test_data.append(resized_arr)
    
test = np.array(test_data)
print(test.shape)
# Out:
# ['482.jpeg', '457.jpeg', '146.jpeg', '315.jpeg', '49.jpeg', '172.jpeg', '422.jpeg', '498.jpeg', '304.jpeg', '490.jpeg', '542.jpeg', '211.jpeg', '321.jpeg', '493.jpeg', '111.jpeg', '444.jpeg', '364.jpeg', '609.jpeg', '165.jpeg', '583.jpeg', '567.jpeg', '192.jpeg', '224.jpeg', '60.jpeg', '593.jpeg', '1.jpeg', '513.jpeg', '606.jpeg', '64.jpeg', '201.jpeg', '506.jpeg', '206.jpeg', '451.jpeg', '559.jpeg', '163.jpeg', '445.jpeg', '528.jpeg', '190.jpeg', '39.jpeg', '297.jpeg', '546.jpeg', '219.jpeg', '475.jpeg', '305.jpeg', '7.jpeg', '92.jpeg', '471.jpeg', '151.jpeg', '246.jpeg', '45.jpeg', '368.jpeg', '334.jpeg', '180.jpeg', '616.jpeg', '436.jpeg', '85.jpeg', '446.jpeg', '299.jpeg', '376.jpeg', '561.j
212.jpeg', '543.jpeg', '46.jpeg', '402.jpeg', '80.jpeg', '572.jpeg', '260.jpeg', '618.jpeg', '91.jpeg', '381.jpeg', '8.jpeg', '15.jpeg', '90.jpeg', '25.jpeg', '110.jpeg', '10.jpeg', '75.jpeg', '310.jpeg', '439.jpeg', '461.jpeg', '258.jpeg', '173.jpeg', '87.jpeg', '309.jpeg', '495.jpeg', '440.jpeg', '296.jpeg', '250.jpeg', '584.jpeg', '551.jpeg', '417.jpeg', '244.jpeg', '558.jpeg', '438.jpeg', '582.jpeg', '383.jpeg', '428.jpeg', '505.jpeg', '164.jpeg', '522.jpeg', '441.jpeg', '282.jpeg', '507.jpeg', '418.jpeg', '449.jpeg', '116.jpeg', '103.jpeg', '427.jpeg', '544.jpeg', '456.jpeg', '170.jpeg', '189.jpeg', '215.jpeg', '454.jpeg', '222.jpeg', '431.jpeg', '580.jpeg', '581.jpeg', '405.jpeg', '134.jpeg', '113.jpeg', '43.jpeg', '198.jpeg', '563.jpeg', '275.jpeg', '20.jpeg', '413.jpeg', '483.jpeg', '519.jpeg', '516.jpeg', '566.jpeg', '254.jpeg', '443.jpeg', '252.jpeg', '604.jpeg', '354.jpeg', '410.jpeg', '325.jpeg', '514.jpeg', '565.jpeg', '286.j ...
# (624, 180, 180)

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
  x_train.append(feature)
  y_train.append(label)

for feature, label in val:
  x_val.append(feature)
  y_val.append(label)

for feature in test:
  x_test.append(feature)
#   y_test.append(label)

# %%
x_train[0]
# Out:
# array([[197,  49,  48, ..., 161,  15,  27],
#        [196, 114,  63, ...,  22,  25,   5],
#        [ 78,  38,  57, ...,  18,   8,  14],
#        ...,
#        [ 28,  28,  28, ...,  22,  23,  23],
#        [ 28,  28,  28, ...,  23,  23,  23],
#        [ 28,  28,  28, ...,  23,  23,  23]], dtype=uint8)

# %%
x_train = np.array(x_train) / 255.
x_val = np.array(x_val) / 255.
x_test = np.array(x_test) / 255.

# %%
x_train = x_train.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
# y_test = np.array(y_test)

# %%
plt.imshow(x_train[0].reshape(180,180), cmap='gray')
print('label = ', y_train[0])
# Out:
# label =  1

# %%
print(len(x_train))
print(len(x_val))
print(len(x_test))
# Out:
# 3662
# 1570
# 624

# %%
fig, ax = plt.subplots(3, 3, figsize=(10, 7))
ax = ax.ravel()
plt.tight_layout()

for i in range(3):
  random_index = random.randint(0, min(len(x_train), len(x_val), len(x_test)))
  ax[i].imshow(x_train[random_index].reshape(180,180), cmap='gray')
  ax[i].set_title('Set: train, label (Pneumonia =) {}'.format(y_train[random_index]))

  ax[i+3].imshow(x_val[random_index].reshape(180,180), cmap='gray')
  ax[i+3].set_title('Set: val, label (Pneumonia =) {}'.format(y_val[random_index]))
  
  ax[i+6].imshow(x_test[random_index].reshape(180,180), cmap='gray')
#   ax[i+6].set_title('Set: test, label (Pneumonia =) {}'.format(y_test[random_index]))

# %%
def conv_block(filters):
  block = tf.keras.Sequential([
    tf.keras.layers.SeparableConv2D(filters, (3,3), activation='relu', padding='same'),
    tf.keras.layers.SeparableConv2D(filters, (3,3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(),    
  ])
  return block

# %%
def dense_block(units, dropout_rate):
  block = tf.keras.Sequential([
    tf.keras.layers.Dense(units, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(dropout_rate),
  ])
  return block

# %%
def build_model():
  model = tf.keras.Sequential([
    tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 1)),
    
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', padding='same'),
    tf.keras.layers.MaxPool2D(),

    conv_block(32),
    conv_block(64),
    
    conv_block(128),
    tf.keras.layers.Dropout(0.2),

    conv_block(256),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Flatten(),
    dense_block(256, 0.7),
    dense_block(128, 0.5),
    dense_block(64, 0.3),
    
    tf.keras.layers.Dense(1, activation='sigmoid')
  ])
  return model

# %%
weight_for_normal = len(x_train) / (2 * count_normal)
weight_for_pneumonia = len(x_train) / (2 * count_pneumonia)

class_weight = {0:weight_for_normal, 1:weight_for_pneumonia}

print('weight for class 0 (normal): {:.3f}'.format(weight_for_normal))
print('weight for class 1 (pneumonia): {:.3f}'.format(weight_for_pneumonia))
# Out:
# weight for class 0 (normal): 1.925
# weight for class 1 (pneumonia): 0.675

# %%
# compile a vanilla model

model_vanilla = build_model()

metrics = [
  'accuracy', 
  tf.keras.metrics.Precision(name='precision'),
  tf.keras.metrics.Recall(name='recall'),
]

model_vanilla.compile(optimizer='adam', loss='binary_crossentropy', metrics=metrics)

# %%
epochs = 30
batch_size = 100

# %%
history_vanilla = model_vanilla.fit(
    x=x_train, 
    y=y_train, 
    epochs=epochs, 
    batch_size=batch_size, 
    validation_data=(x_val,y_val), 
    class_weight=class_weight
)
# Out:
# Epoch 1/30
# 37/37 [==============================] - 51s 1s/step - loss: 0.6503 - accuracy: 0.6436 - precision: 0.8812 - recall: 0.5994 - val_loss: 0.6845 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 2/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.3722 - accuracy: 0.8069 - precision: 0.9626 - recall: 0.7691 - val_loss: 0.5671 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 3/30
# 37/37 [==============================] - 52s 1s/step - loss: 0.2570 - accuracy: 0.8875 - precision: 0.9756 - recall: 0.8698 - val_loss: 0.6298 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 4/30
# 37/37 [==============================] - 52s 1s/step - loss: 0.1918 - accuracy: 0.9238 - precision: 0.9852 - recall: 0.9107 - val_loss: 0.7667 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 5/30
# 37/37 [==============================] - 51s 1s/step - loss: 0.1620 - accuracy: 0.9462 - precision: 0.9846 - recall: 0.9421 - val_loss: 0.8675 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 6/30
# 37/37 [==============================] - 52s 1s/step - loss: 0.1338 - accuracy: 0.9519 - precision: 0.9873 - recall: 0.9473 - val_loss: 0.9360 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 7/30
# 37/37 [==============================] - 52s 1s/step - loss: 0.1208 - accuracy: 0.9569 - precision: 0.9867 - recall: 0.9546 - val_loss: 1.0016 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 8/30
# 37/37 [==============================] - 51s 1s/step - loss: 0.1190 - accuracy: 0.9566 - precision: 0.9881 - recall: 0.9528 - val_loss: 1.0558 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 9/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.1059 - accuracy: 0.9631 - precision: 0.9864 - recall: 0.9635 - val_loss: 1.0574 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 10/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0861 - accuracy: 0.9691 - precision: 0.9920 - recall: 0.9661 - val_loss: 1.1177 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 11/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0887 - accuracy: 0.9661 - precision: 0.9883 - recall: 0.9657 - val_loss: 1.2537 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 12/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0841 - accuracy: 0.9735 - precision: 0.9891 - recall: 0.9749 - val_loss: 1.3327 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 13/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0875 - accuracy: 0.9667 - precision: 0.9924 - recall: 0.9624 - val_loss: 1.4224 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 14/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0753 - accuracy: 0.9730 - precision: 0.9925 - recall: 0.9709 - val_loss: 1.4860 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 15/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0599 - accuracy: 0.9812 - precision: 0.9936 - recall: 0.9808 - val_loss: 1.5970 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 16/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0687 - accuracy: 0.9760 - precision: 0.9899 - recall: 0.9775 - val_loss: 1.5295 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 17/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0541 - accuracy: 0.9803 - precision: 0.9948 - recall: 0.9786 - val_loss: 1.4361 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 18/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0451 - accuracy: 0.9866 - precision: 0.9959 - recall: 0.9860 - val_loss: 1.1929 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 19/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0450 - accuracy: 0.9842 - precision: 0.9959 - recall: 0.9827 - val_loss: 0.9049 - val_accuracy: 0.7605 - val_precision: 0.7571 - val_recall: 1.0000
# Epoch 20/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0333 - accuracy: 0.9904 - precision: 0.9970 - recall: 0.9900 - val_loss: 0.5103 - val_accuracy: 0.8376 - val_precision: 0.8213 - val_recall: 1.0000
# Epoch 21/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0349 - accuracy: 0.9853 - precision: 0.9959 - recall: 0.9841 - val_loss: 0.1247 - val_accuracy: 0.9618 - val_precision: 0.9520 - val_recall: 0.9991
# Epoch 22/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0402 - accuracy: 0.9853 - precision: 0.9952 - recall: 0.9849 - val_loss: 0.1048 - val_accuracy: 0.9650 - val_precision: 0.9567 - val_recall: 0.9983
# Epoch 23/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0363 - accuracy: 0.9861 - precision: 0.9963 - recall: 0.9849 - val_loss: 0.0628 - val_accuracy: 0.9745 - val_precision: 0.9888 - val_recall: 0.9770
# Epoch 24/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0488 - accuracy: 0.9839 - precision: 0.9933 - recall: 0.9849 - val_loss: 0.0579 - val_accuracy: 0.9790 - val_precision: 0.9888 - val_recall: 0.9829
# Epoch 25/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0478 - accuracy: 0.9823 - precision: 0.9951 - recall: 0.9808 - val_loss: 0.0666 - val_accuracy: 0.9809 - val_precision: 0.9847 - val_recall: 0.9898
# Epoch 26/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0304 - accuracy: 0.9888 - precision: 0.9978 - recall: 0.9871 - val_loss: 0.0969 - val_accuracy: 0.9752 - val_precision: 0.9693 - val_recall: 0.9983
# Epoch 27/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0298 - accuracy: 0.9888 - precision: 0.9967 - recall: 0.9882 - val_loss: 0.0951 - val_accuracy: 0.9694 - val_precision: 0.9956 - val_recall: 0.9633
# Epoch 28/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0213 - accuracy: 0.9918 - precision: 0.9978 - recall: 0.9911 - val_loss: 0.1920 - val_accuracy: 0.9510 - val_precision: 0.9973 - val_recall: 0.9369
# Epoch 29/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0361 - accuracy: 0.9869 - precision: 0.9963 - recall: 0.9860 - val_loss: 0.1142 - val_accuracy: 0.9675 - val_precision: 0.9947 - val_recall: 0.9616
# Epoch 30/30
# 37/37 [==============================] - 50s 1s/step - loss: 0.0207 - accuracy: 0.9926 - precision: 0.9989 - recall: 0.9911 - val_loss: 0.0690 - val_accuracy: 0.9796 - val_precision: 0.9922 - val_recall: 0.9804

# %%
epochs_array = [i for i in range(epochs)]
fig, ax = plt.subplots(1,3)
train_precision = history_vanilla.history['precision']
train_recall = history_vanilla.history['recall']
train_loss = history_vanilla.history['loss']

val_precision = history_vanilla.history['val_precision']
val_recall = history_vanilla.history['val_recall']
val_loss = history_vanilla.history['val_loss']
fig.set_size_inches(20,5)

ax[0].plot(epochs_array, train_loss, 'g-o', label='Training Loss')
ax[0].plot(epochs_array, val_loss, 'r-o', label='Validation Loss')
ax[0].set_title('Training & Validation Loss')
ax[0].legend()
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].grid(True)

ax[1].plot(epochs_array, train_precision, 'go-', label='Training Precision')
ax[1].plot(epochs_array, val_precision, 'ro-', label='Validation Precision')
ax[1].set_title('Training & Validation Precision')
ax[1].legend()
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Precision')
ax[1].grid(True)

ax[2].plot(epochs_array, train_recall, 'go-', label='Training Recall')
ax[2].plot(epochs_array, val_recall, 'ro-', label='Validation Recall')
ax[2].set_title('Training & Validation Recall')
ax[2].legend()
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Recall')
ax[2].grid(True)

plt.show()

# %%
def print_results(y_test, y_pred):
    print('Accuracy   : {:.5f}'.format(accuracy_score(y_pred , y_test))) 
    print('AUC        : {:.5f}'.format(roc_auc_score(y_test , y_pred)))
    print('Precision  : {:.5f}'.format(precision_score(y_test , y_pred)))
    print('Recall     : {:.5f}'.format(recall_score(y_test , y_pred)))
    print('F1         : {:.5f}'.format(f1_score(y_test , y_pred)))
    print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred))

# %%
predictions = model_vanilla.predict(x=x_test)
y_pred = np.round(predictions).reshape(1,-1)[0]
# print_results(y_test, y_pred)

# %%
# compile fine tuned model

model_ft = build_model()

metrics = [
  'accuracy', 
  tf.keras.metrics.Precision(name='precision'),
  tf.keras.metrics.Recall(name='recall'),
]

model_ft.compile(optimizer='adam', loss='binary_crossentropy', metrics=metrics)

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint('xray_model.h5', save_best_only=True)
early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, mode='min', verbose=1, restore_best_weights=True)

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
epochs = 100
batch_size = 32

# %%
history_ft = model_ft.fit(
    x=x_train, 
    y=y_train, 
    epochs=epochs, 
    batch_size=batch_size, 
    validation_data=(x_val,y_val), 
    class_weight=class_weight,
    callbacks = [checkpoint_cb, early_stopping_cb, lr_scheduler]
)
# Out:
# Epoch 1/100
# 115/115 [==============================] - 50s 436ms/step - loss: 0.4385 - accuracy: 0.7840 - precision: 0.9372 - recall: 0.7591 - val_loss: 1.0131 - val_accuracy: 0.7465 - val_precision: 0.7465 - val_recall: 1.0000
# Epoch 2/100
# 115/115 [==============================] - 50s 432ms/step - loss: 0.2544 - accuracy: 0.9009 - precision: 0.9666 - recall: 0.8971 - val_loss: 3.1108 - val_accuracy: 0.3000 - val_precision: 1.0000 - val_recall: 0.0623
# Epoch 3/100
# 115/115 [==============================] - 50s 432ms/step - loss: 0.2057 - accuracy: 0.9219 - precision: 0.9776 - recall: 0.9155 - val_loss: 0.1070 - val_accuracy: 0.9599 - val_precision: 0.9751 - val_recall: 0.9710
# Epoch 4/100
# 115/115 [==============================] - 50s 431ms/step - loss: 0.2017 - accuracy: 0.9214 - precision: 0.9768 - recall: 0.9155 - val_loss: 0.3270 - val_accuracy: 0.8924 - val_precision: 0.9980 - val_recall: 0.8575
# Epoch 5/100
# 115/115 [==============================] - 50s 432ms/step - loss: 0.1571 - accuracy: 0.9372 - precision: 0.9844 - recall: 0.9299 - val_loss: 0.1029 - val_accuracy: 0.9656 - val_precision: 0.9737 - val_recall: 0.9804
# Epoch 6/100
# 115/115 [==============================] - 50s 431ms/step - loss: 0.1525 - accuracy: 0.9410 - precision: 0.9815 - recall: 0.9380 - val_loss: 0.1767 - val_accuracy: 0.9280 - val_precision: 0.9963 - val_recall: 0.9070
# Epoch 7/100
# 115/115 [==============================] - 50s 432ms/step - loss: 0
# 115/115 [==============================] - 50s 435ms/step - loss: 0.0250 - accuracy: 0.9926 - precision: 0.9981 - recall: 0.9919 - val_loss: 0.0869 - val_accuracy: 0.9739 - val_precision: 0.9948 - val_recall: 0.9701
# Epoch 36/100
# 115/115 [==============================] - 50s 435ms/step - loss: 0.0215 - accuracy: 0.9918 - precision: 0.9993 - recall: 0.9897 - val_loss: 0.0719 - val_accuracy: 0.9783 - val_precision: 0.9931 - val_recall: 0.9778
# Epoch 37/100
# 115/115 [==============================] - 50s 434ms/step - loss: 0.0287 - accuracy: 0.9921 - precision: 0.9985 - recall: 0.9908 - val_loss: 0.0745 - val_accuracy: 0.9758 - val_precision: 0.9930 - val_recall: 0.9744
# Epoch 38/100
# 115/115 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9940 - precision: 0.9985 - recall: 0.9934Restoring model weights from the end of the best epoch.
# 115/115 [==============================] - 50s 435ms/step - loss: 0.0202 - accuracy: 0.9940 - precision: 0.9985 - recall: 0.9934 - val_loss: 0.0727 - val_accuracy: 0.9758 - val_precision: 0.9930 - val_recall: 0.9744
# Epoch 00038: early stopping

# %%
epochs_array = [i for i in range(len(history_ft.history['accuracy']))]
fig, ax = plt.subplots(1,3)
train_precision = history_ft.history['precision']
train_recall = history_ft.history['recall']
train_loss = history_ft.history['loss']

val_precision = history_ft.history['val_precision']
val_recall = history_ft.history['val_recall']
val_loss = history_ft.history['val_loss']
fig.set_size_inches(20,5)

ax[0].plot(epochs_array, train_loss, 'g-o', label='Training Loss')
ax[0].plot(epochs_array, val_loss, 'r-o', label='Validation Loss')
ax[0].set_title('Training & Validation Loss')
ax[0].legend()
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].grid(True)

ax[1].plot(epochs_array, train_precision, 'go-', label='Training Precision')
ax[1].plot(epochs_array, val_precision, 'ro-', label='Validation Precision')
ax[1].set_title('Training & Validation Precision')
ax[1].legend()
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Precision')
ax[1].grid(True)

ax[2].plot(epochs_array, train_recall, 'go-', label='Training Recall')
ax[2].plot(epochs_array, val_recall, 'ro-', label='Validation Recall')
ax[2].set_title('Training & Validation Recall')
ax[2].legend()
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Recall')
ax[2].grid(True)
plt.show()

# %%
predictions = model_ft.predict(x=x_test)
y_pred = np.round(predictions).reshape(1,-1)[0]
print(test_files[0])
fig, ax = plt.subplots(5,6, figsize=(8, 8))
ax = ax.ravel()
plt.tight_layout()

for i in range(30):#簡單print 出30個預測圖,0為Normal, 1為Pneumonia
    ax[i].imshow(x_test[i].reshape(180,180), cmap='gray')
    ax[i].set_title(' {}'.format(y_pred[i]))
    i=i+1
#     print('label = ', y_pred[i])
# Out:
# /home/wcislab/NTHU_Medical/chest_xray/test2/482.jpeg

# %%
# print_results(y_test, y_pred)

# %%
#將jpeg以及predict結果輸入成dataframe再轉出csv檔
from pandas.core.frame import DataFrame
a=img_handle
b=y_pred
c={"case":a,"predict":b}
data=DataFrame(c)
print(data)
data.to_csv(path+'/109064518_高聖哲.csv',index=False)
# Out:
#          case  predict
# 0    482.jpeg      1.0
# 1    457.jpeg      1.0
# 2    146.jpeg      1.0
# 3    315.jpeg      1.0
# 4     49.jpeg      0.0
# ..        ...      ...
# 619  601.jpeg      1.0
# 620   35.jpeg      1.0
# 621  347.jpeg      1.0
# 622  403.jpeg      1.0
# 623  155.jpeg      1.0
#
# [624 rows x 2 columns]
